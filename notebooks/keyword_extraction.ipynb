# %% [markdown]
# <h3><ul>
#     <li><strong><span style="font-family: 'Trebuchet MS', Helvetica, sans-serif;">Keyword Extraction</span></strong></li>
# </ul></h3>

# %%
import yake
import pandas as pd

dataset = pd.read_excel('./data/clean_data_tranlsated.xlsx')

# %%
language = "en"
max_ngram_size = 5
duplication_threshold = 0.9
numOfKeywords = 1

custom_kw_extractor = yake.KeywordExtractor(lan=language,
                                            n=max_ngram_size,
                                            dedupLim=duplication_threshold,
                                            top=numOfKeywords,
                                            features=None)

# %%
def get_keywords(row):
    '''Keyword extraction on Keywords and Short Keywords'''
    description_keywords = custom_kw_extractor.extract_keywords(row.translated_description)
    if len(description_keywords) == 0:
        description_keywords = ''
    elif len(description_keywords) == 1:
        description_keywords = description_keywords[0][0]
    else:
        description_keywords = ' '.join([i[0] for i in description_keywords])
        # print(row)
    row['keywords'] = description_keywords

    return row

dataset = dataset.apply(get_keywords, axis=1)

# %%
dataset.sample(20)
# Out:
#       Unnamed: 0                                  short_description  \
# 235          235       erp SID_34 account unlock and password reset
# 4372        4372  job SID_37hotf failed in job_scheduler at: 09/...
# 2968        2968                    setup new ws \zlnfpuam aktplhre
# 5721        5721  please switch of tr telephony_software today f...
# 33            33                                 ess password reset
# 5775        5775  can you tell me the phone number for office 44...
# 2586        2586  job Job_3049 failed in job_scheduler at: 10/02...
# 1081        1081                                             用友软件问题
# 1850        1850  reset passwords for fylrosuk kedgmiul using pa...
# 4777        4777  job Job_1148 failed in job_scheduler at: 09/11...
# 7732        7732           abended job in job_scheduler: SID_38hotf
# 7607        7607                        network drives disconnected
# 592          592  job Job_593 failed in job_scheduler at: 10/24/...
# 8214        8214                            password reset request.
# 7687        7687  the computer for mii at us_plant facility has ...
# 5951        5951  job SID_11_uacyltoe hxgaycze5 failed in job_sc...
# 5182        5182         expense reports submissions in my workflow
# 3454        3454  picture in collaboration_platform / outlook / ...
# 4647        4647           unable to connect wireless on the laptop
# 4758        4758  job SID_37hoti failed in job_scheduler at: 09/...
#
#                                             description             caller  \
# 235        erp SID_34 account unlock and password reset  jfsmwpny klxsdqiw
# 4372  received from: monitoring_tool@company.com\n\n...  bpctwhsn kzqsbmtp
# 2968                    setup new ws \zlnfpuam aktplhre  zlnfpuam aktplhre
# 5721  this is last call meeting that was set up by f...  djpwfxzt cfkwxlmq
# 33                                   ess password reset  fsqwkbez eudsantq
# 5775  \n\nreceived from: azxhejvq.fyemlavd@gmail.com...  azxhejvq fyemlavd
# 2586  received from: monitoring_tool@company.com\n\n...  bpctwhsn kzqsbmtp
# 1081                打开已关闭的销售订单时,显示"不能在手动或分布事物方式下创建新的链接"  bwstnmjh yqumwrsk
# 1850  reset passwords for fylrosuk kedgmiul using pa...  fylrosuk kedgmiul
# 4777  received from: monitoring_tool@company.com\n\n...  bpctwhsn kzqsbmtp
# 7732  received from: monitoring_tool@company.com\n\n...  ZkBogxib QsEJzdZO
# 7607                      unable to connect to t drive   vanteksj astelnqw
# 592   received from: monitoring_tool@company.com\n\n...  bpctwhsn kzqsbmtp
# 8214                            password reset request.  kcqzrgef awnjdlyr
# 7687  the computer for mii has got thrown out of com...  dpuifqeo eglwsfkn
# 5951  received from: monitoring_tool@company.com\n\n...  bpctwhsn kzqsbmtp
# 5182  \n\nreceived from: sbvlxuwm.yanbikrx@gmail.com...  sbvlxuwm yanbikrx
# 3454  my profile shows different pictures on collabo...  gwrkhufx gsfrlqwi
# 4647           unable to connect wireless on the laptop  nouivdea boiypjvx
# 4758  received from: monitoring_tool@company.com\n\n...  bpctwhsn kzqsbmtp
#
#        group  char_length  word_length  short_char_length  short_word_length  \
# 235    GRP_0           44            7                 44                  7
# 4372   GRP_5          106           11                 64                  8
# 2968  GRP_24           31            5                 31                  5
# 5721   GRP_7          225           45                 68                 11
# 33     GRP_0           18            3                 18                  3
# 5775   GRP_0          127           12                 64                 14
# 2586   GRP_8          104           11                 62                  8
# 1081  GRP_48           35            1                  6                  1
# 1850  GRP_17           84            9                 84                  9
# 4777   GRP_9          104           11                 62                  8
# 7732   GRP_8          106           11                 40                  5
# 7607   GRP_0           29            6                 27                  3
# 592    GRP_8          103           11                 61                  8
# 8214   GRP_0           23            3                 23                  3
# 7687   GRP_3          112           19                 78                 14
# 5951   GRP_5          121           12                 79                  9
# 5182   GRP_0          274           38                 42                  6
# 3454  GRP_16          173           25                 69                  9
# 4647   GRP_0           40            7                 40                  7
# 4758   GRP_5          106           11                 64                  8
#
#       group_code  ...                          cleaned_short_description  \
# 235            0  ...             erp sid  account unlock password reset
# 4372          45  ...                    job sid hotf fail job scheduler
# 2968          17  ...                              setup new ws zlnfpuam
# 5721          67  ...         switch tr telephony software today     cet
# 33             0  ...                                 ess password reset
# 5775           0  ...                tell phone number office  usx tower
# 2586          72  ...                        job job  fail job scheduler
# 1081          43  ...                                                NaN
# 1850           9  ...  reset password use password management tool pa...
# 4777          73  ...                        job job  fail job scheduler
# 7732          72  ...                  abende job job scheduler sid hotf
# 7607           0  ...                           network drive disconnect
# 592           72  ...                        job job  fail job scheduler
# 8214           0  ...                             password reset request
# 7687          23  ...  computer mii us plant facility get throw compa...
# 5951          45  ...      job sid  uacyltoe hxgaycze fail job scheduler
# 5182           0  ...                 expense report submission workflow
# 3454           8  ...  picture collaboration platform outlook skype u...
# 4647           0  ...                     unable connect wireless laptop
# 4758          45  ...                    job sid hoti fail job scheduler
#
#      cleaned_char_length cleaned_word_length  cleaned_short_char_length  \
# 235                   38                   6                         38
# 4372                  31                   6                         31
# 2968                  21                   4                         21
# 5721                 102                  17                         42
# 33                    18                   3                         18
# 5775                  60                   7                         35
# 2586                  27                   5                         27
# 1081                   0                   0                          0
# 1850                  58                   8                         58
# 4777                  27                   5                         27
# 7732                  33                   6                         33
# 7607                  20                   3                         24
# 592                   27                   5                         27
# 8214                  22                   3                         22
# 7687                  53                   9                         55
# 5951                  45                   7                         45
# 5182                 116                  16                         34
# 3454                 128                  17                         59
# 4647                  30                   4                         30
# 4758                  31                   6                         31
#
#       cleaned_short_word_length  \
# 235                           6
# 4372                          6
# 2968                          4
# 5721                          6
# 33                            3
# 5775                          6
# 2586                          5
# 1081                          0
# 1850                          8
# 4777                          5
# 7732                          6
# 7607                          3
# 592                           5
# 8214                          3
# 7687                          9
# 5951                          7
# 5182                          4
# 3454                          7
# 4647                          4
# 4758                          6
#
#                                      merged_description  language  \
# 235              erp sid  account unlock password reset        en
# 4372                    job sid hotf fail job scheduler        en
# 2968                              setup new ws zlnfpuam        en
# 5721  switch tr telephony software today     cet ts ...        en
# 33                                   ess password reset        en
# 5775  tell phone number office  usx tower mikhghytr ...        en
# 2586                        job job  fail job scheduler        en
# 1081         用友软件问题 打开已关闭的销售订单时,显示"不能在手动或分布事物方式下创建新的链接"        zh
# 1850  reset password use password management tool pa...        en
# 4777                        job job  fail job scheduler        en
# 7732                  abende job job scheduler sid hotf        en
# 7607            network disconnect unable connect drive        en
# 592                         job job  fail job scheduler        en
# 8214                             password reset request        en
# 7687  us plant facility computer mii get throw compa...        en
# 5951      job sid  uacyltoe hxgaycze fail job scheduler        en
# 5182  expense accord oneteam jashyht mkuhtyhui   par...        en
# 3454  user faerfrtbj profile show different picture ...        en
# 4647                     unable connect wireless laptop        en
# 4758                    job sid hoti fail job scheduler        en
#
#      language_confidence                             translated_description  \
# 235             0.606594             erp sid  account unlock password reset
# 4372            0.745099                    job sid hotf fail job scheduler
# 2968            0.321603                              setup new ws zlnfpuam
# 5721            0.728534  switch tr telephony software today     cet ts ...
# 33              0.433673                                 ess password reset
# 5775            0.454968  tell phone number office  usx tower mikhghytr ...
# 2586            0.893109                        job job  fail job scheduler
# 1081            0.974744  When opening closed sales orders with a friend...
# 1850            0.595499  reset password use password management tool pa...
# 4777            0.893109                        job job  fail job scheduler
# 7732            0.557620                  abende job job scheduler sid hotf
# 7607            0.775043            network disconnect unable connect drive
# 592             0.893109                        job job  fail job scheduler
# 8214            0.567777                             password reset request
# 7687            0.871650  us plant facility computer mii get throw compa...
# 5951            0.654041      job sid  uacyltoe hxgaycze fail job scheduler
# 5182            0.895613  expense accord oneteam jashyht mkuhtyhui   par...
# 3454            0.660278  user faerfrtbj profile show different picture ...
# 4647            0.642863                     unable connect wireless laptop
# 4758            0.710405                    job sid hoti fail job scheduler
#
#                                           keywords
# 235                erp sid account unlock password
# 4372                   sid hotf fail job scheduler
# 2968                         setup new ws zlnfpuam
# 5721        call meeting set fhtyulvio participate
# 33                              ess password reset
# 5775                 phone number office usx tower
# 2586                    job job fail job scheduler
# 1081                   opening closed sales orders
# 1850       password management tool password reset
# 4777                    job job fail job scheduler
# 7732                  abende job job scheduler sid
# 7607       network disconnect unable connect drive
# 592                     job job fail job scheduler
# 8214                        password reset request
# 7687                company domain contact ms info
# 5951          uacyltoe hxgaycze fail job scheduler
# 5182      expense accord oneteam jashyht mkuhtyhui
# 3454  picture collaboration platform outlook skype
# 4647                unable connect wireless laptop
# 4758                   sid hoti fail job scheduler
#
# [20 rows x 22 columns]

# %%
dataset.columns
# Out:
# Index(['Unnamed: 0', 'short_description', 'description', 'caller', 'group',
#        'char_length', 'word_length', 'short_char_length', 'short_word_length',
#        'group_code', 'char_length_bins', 'cleaned_description',
#        'cleaned_short_description', 'cleaned_char_length',
#        'cleaned_word_length', 'cleaned_short_char_length',
#        'cleaned_short_word_length', 'merged_description', 'language',
#        'language_confidence', 'translated_description', 'keywords'],
#       dtype='object')

# %%
cols = ['translated_description', 'keywords',
       'short_description', 'description', 'group',
       'cleaned_description', 'cleaned_short_description', 'merged_description',
       'char_length', 'word_length', 'short_char_length', 'short_word_length',
       'language', 'language_confidence',]

# %%
dataset.to_csv('./data/preprocessed_data.csv', index=None, columns=cols)
dataset.to_excel('./data/preprocessed_data.xlsx', index=None, columns=cols)
